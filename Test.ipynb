# %%
## phase 1: Load and observe
import pandas as pd
import numpy as np
import glob
import os
# globe - to acces all csv
path = "data"
all_files = glob.glob(os.path.join(path, "**", "*.csv"), recursive=True)
# print(all_files)
dfs = [pd.read_csv(files) for files in all_files] # combine all of them
combined_df=pd.concat(dfs,ignore_index=True) # ignore_index does 
# print(combined_df.head())
# print(combined_df.shape)
print(combined_df.tail())
# Out:
#                date      state   district  pincode  bio_age_5_17  bio_age_17_  \
# 4938832  31-12-2025  Telangana  Hyderabad   500045           NaN          NaN
# 4938833  31-12-2025  Telangana  Hyderabad   500057           NaN          NaN
# 4938834  31-12-2025  Telangana  Hyderabad   500061           NaN          NaN
# 4938835  31-12-2025  Telangana  Hyderabad   500062           NaN          NaN
# 4938836  31-12-2025  Telangana  Hyderabad   500095           NaN          NaN
#
#          demo_age_5_17  demo_age_17_  age_0_5  age_5_17  age_18_greater
# 4938832            NaN           NaN      4.0       5.0             1.0
# 4938833            NaN           NaN      0.0       2.0             0.0
# 4938834            NaN           NaN      4.0       2.0             0.0
# 4938835            NaN           NaN      1.0       4.0             0.0
# 4938836            NaN           NaN      0.0       1.0             0.0

# %%
## phase 2: identify mess type
from logging import PlaceHolder
import pandas as pd
import numpy as np
import glob
import os
path="data"
all_files=glob.glob(os.path.join(path,"**","*.csv"),recursive=True)
dfs=[pd.read_csv(files) for files in all_files]
combined_df=pd.concat(dfs,ignore_index=True)
standard_Nans=combined_df.isna().sum()  ## no of nan's
# print(standard_Nans)
duplicates=combined_df.duplicated().sum()   ## no of duplicates
# print(duplicates)
# Out:
# 591454

# %%
import pandas as pd
import numpy as np
import glob
import os
patch = "data"
all_files=glob.glob(os.path.join(path,"**","*csv")recursive=True)
dfs=[pd.read_csv(files) for files in all_files]
combined_df=pd.concat(dfs,ignore_index=True)
